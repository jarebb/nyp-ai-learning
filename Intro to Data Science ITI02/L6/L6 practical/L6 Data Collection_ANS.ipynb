# %% [markdown]
# # L6 Data Collection
#
# In this practical, you learn
# * how to scrap web pages using Scrapy and extract the content using XPath, regex, and CSSSelector with LXML

# %% [markdown]
# Useful Tools for Regex, XPath and CSSSelector development
# Crawling and extraction rely heavily on the usage of XPath, and CSS Selector. However developing these patterns from scratch might be challenging, you might find some of the following tools useful.
#
# XPath Wizard
# https://chrome.google.com/webstore/detail/xpath-helper-wizard/jadhpggafkbmpdpmpgigopmodldgfcki?hl=en
#
# Selector Gadget
# https://chrome.google.com/webstore/detail/selectorgadget/mhjhnkcfbdhnjickkkdbjoemdmbfginb?hl=en

# %% [markdown]
# ## Focused crawl
#
# First let's consider a simple crawler which crawl a quotes website using focused crawl strategy.
# [quotes.toscrape.com](http://quotes.toscrape.com/)
#
#
# Suppose that by navigating the website, we are able to guess the list of pages is in the shape of
# `http://quotes.toscrape.com/page/1/`,
# `http://quotes.toscrape.com/page/2/`,
#
# The quotes.toscrape example is inspired by [https://www.jitsejan.com/using-scrapy-in-jupyter-notebook.html ].
#
# Recall from the lecture note that a focused crawl behaves as follows,
#
# 1. For each URL `u` in the list of seed URLs,
#      1. extract the needed content from `u`.
#
# We can use a function or just hard coding to generate the sequence of start / seed URLs.
#
# Note that a focused crawl does not follow links in the pages. We get a page from the list, and extract the needed content.
#
#
# First of all we need to define some writer classes, which help to debug or save the output of the extract.
#
#  * ```ConsoleWriterPipeline``` receives the extract result from the spider and prints out the content.
#  * ```JsonWriterPipeline``` receives the extract result from the spider and appends them into a JSON Line file, (each line is a json)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir_path='/content/drive/My Drive/Data/DS6/'

# %%
import lxml.etree

import json

# receives the extract result from the spider and prints out the content
class ConsoleWriterPipeline(object):
    def open_spider(self, spider):
        None
    def close_spdier(self, spider):
        None
    
    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        print(line)
        return item
    
# receives the extract result from the spider and appends them into a JSON Line file, (each line is a json)
class JsonWriterPipeline(object):
    def open_spider(self, spider):
        self.file = open(data_dir_path+'result.json', 'w')

    def close_spider(self, spider):
        print('JSON File Generated')
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %% [markdown]
# Next we define our spider, `QuoteSpider` is a focused spider.
#
# It reads a list of URLs and calls `parse()` for each page (`response`) given by the link.
#
# Note that for each link, we find multiple quotes. Hence, in `parse()` we use a CSS selector to retrieve the list of all `div` elements that containing the quotes, one quote per element.
#
# The `yield` statement constructs the result JSON object that will be consumed by the downstream writer, in this case we use `ConsoleWriterPipeline`.
#
#
# ![image](https://drive.google.com/uc?id=13tZtcspz_KFJecaNMs8ZQt3RnYz3qHWI)

# %% [markdown]
# ```
# for quote in response.css('div.quote'):
#             yield {
#                 'text': quote.css('span.text::text').get(),
#                 'author': quote.css('span small::text').get(),
#                 'tags': quote.css('div.tags a.tag::text').getall(),
#             }
# ```

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.6.1-py2.py3-none-any.whl (264 kB)
#      |████████████████████████████████| 264 kB 5.5 MB/s
# Collecting parsel>=1.5.0
#   Downloading parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# Collecting itemloaders>=1.0.1
#   Downloading itemloaders-1.0.4-py3-none-any.whl (11 kB)
# Collecting queuelib>=1.4.2
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting tldextract
#   Downloading tldextract-3.3.0-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 1.7 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from scrapy) (57.4.0)
# Collecting cryptography>=2.0
#   Downloading cryptography-37.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 46.3 MB/s
# Collecting pyOpenSSL>=16.2.0
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.2 MB/s
# Collecting PyDispatcher>=2.0.5
#   Downloading PyDispatcher-2.0.5.zip (47 kB)
#      |████████████████████████████████| 47 kB 4.2 MB/s
# Requirement already satisfied: lxml>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from scrapy) (4.2.6)
# Collecting w3lib>=1.17.0
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting Twisted>=17.9.0
#   Downloading Twisted-22.4.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 32.0 MB/s
# Collecting zope.interface>=4.1.3
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 47.9 MB/s
# Collecting service-identity>=16.0.0
#   Downloading service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# Collecting protego>=0.1.15
#   Downloading Protego-0.2.1-py2.py3-none-any.whl (8.2 kB)
# Collecting cssselect>=0.9.1
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting itemadapter>=0.1.0
#   Downloading itemadapter-0.5.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->scrapy) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->scrapy) (2.21)
# Collecting jmespath>=0.9.5
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: six>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from parsel>=1.5.0->scrapy) (1.15.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from service-identity>=16.0.0->scrapy) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from Twisted>=17.9.0->scrapy) (4.2.0)
# Collecting Automat>=0.8.0
#   Downloading Automat-20.2.0-py2.py3-none-any.whl (31 kB)
# Collecting incremental>=21.3.0
#   Downloading incremental-21.3.0-py2.py3-none-any.whl (15 kB)
# Collecting hyperlink>=17.1.1
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 3.0 MB/s
# Collecting constantly>=15.1
#   Downloading constantly-15.1.0-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.7/dist-packages (from hyperlink>=17.1.1->Twisted>=17.9.0->scrapy) (2.10)
# Collecting requests-file>=1.4
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (2.23.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract->scrapy) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2021.10.8)
# Building wheels for collected packages: PyDispatcher
#   Building wheel for PyDispatcher (setup.py) ... done
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11516 sha256=bac4e939eef8f269d19e6c4e1a9fb273beb053f411d65f946558829f45757d29
#   Stored in directory: /root/.cache/pip/wheels/2d/18/21/3c6a732eaa69a339198e08bb63b7da2c45933a3428b29ec454
# Successfully built PyDispatcher
# Installing collected packages: w3lib, cssselect, zope.interface, requests-file, parsel, jmespath, itemadapter, incremental, hyperlink, cryptography, constantly, Automat, Twisted, tldextract, service-identity, queuelib, pyOpenSSL, PyDispatcher, protego, itemloaders, scrapy
# Successfully installed Automat-20.2.0 PyDispatcher-2.0.5 Twisted-22.4.0 constantly-15.1.0 cryptography-37.0.2 cssselect-1.1.0 hyperlink-21.0.0 incremental-21.3.0 itemadapter-0.5.0 itemloaders-1.0.4 jmespath-1.0.0 parsel-1.6.0 protego-0.2.1 pyOpenSSL-22.0.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.6.1 service-identity-21.1.0 tldextract-3.3.0 w3lib-1.22.0 zope.interface-5.4.0

# %%
import logging
import scrapy
from scrapy.crawler import CrawlerProcess

class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        'http://quotes.toscrape.com/page/1/',
        'http://quotes.toscrape.com/page/2/',
    ]
    custom_settings = {
        'LOG_LEVEL': logging.WARNING,                            # Default : Debug
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}  # Used for pipeline
    }
    
    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
                'text': quote.css('span.text::text').get(),
                'author': quote.css('span small::text').get(),
                'tags': quote.css('div.tags a.tag::text').getall(),
            }

# %% [markdown]
# In the following, we create a process which will start the crawler. By uncommenting and running the below code, we perform the focused crawl the web site. The result will be printed in the output sessoin. In case it does not stop. You consider click the "Block Square" button below the menu bar to stop the kernel.
#
# *Note* In case you hit the `ReactorNotRestartable: ` error, you should comment away another crawler processes in this note book and restart the kernel.

# %% [markdown]
# User Agent is the runner that we use to execute the crawling process.
#
# For more details, refer to https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/User-Agent

# %%
# uncomment me and run
# '''
quotes_crawler_process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

quotes_crawler_process.crawl(QuotesSpider)
quotes_crawler_process.start()
# '''
# Out:
# 2022-05-11 06:02:54 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-05-11 06:02:54 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.4.0, Python 3.7.13 (default, Apr 24 2022, 01:04:09) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.3 3 May 2022), cryptography 37.0.2, Platform Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic
# 2022-05-11 06:02:54 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# JSON File Generated

# %% [markdown]
# ## Exercise
#
# When you are happy with result, you may modify the `QuotesSpider` class to use `JSONWriterPipeline` to save the result in a file.

# %% [markdown]
# ##  Question
#
# Manually getting the list of input URLs for a focused crawl could be challenging? Is there anyway to automate it?
#
# In the following example, we are going to BBC and get the headline and introduction from all the pages that can be access the landing URL.

# %% [markdown]
# ## General Crawl - News Crawler
#
# Restart Runtime to avoid ReactorNotRestartable error.

# %% [markdown]
# At the http://www.bbc.co.uk/news/technology/ page parse the articles.
#
# Get each article text for headline and introduction.
#
# Setup the parsing result either console or json file.

# %%
import lxml.etree

import json
    
class ConsoleWriterPipeline(object):
    def open_spider(self, spider):
        None
    def close_spider(self, spider):
        None
    
    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        print(line)
        return item
    
class JsonWriterPipeline(object):
    def open_spider(self, spider):
        self.file = open(data_dir_path+'newsresult.json', 'w')

    def close_spider(self, spider):
        print('JSON File Generated')
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %% [markdown]
# Define the start Url
#
#
# ```
# "http://www.bbc.co.uk/news/technology/"
# ```
#
# Set the rule for the parsing in the URL
#
# ```
# Rule(LinkExtractor(allow=['/technology-\d+'])
# ```
#
# Parsing function to extract each article headline and introduction
#
# ```
#     story = NewsItem()
#     story['headline'] = response.xpath('//head/title/text()').get()
#     story['intro'] = response.xpath('//p/b/text()').get()
#
#     yield {
#         "headline":story['headline'],
#         "intro":story['intro']
#         }
# ```

# %% [markdown]
# Tag for the Headline
#
# ![image](https://drive.google.com/uc?id=19r3WBTOHK3tj6k55I7h-tXWOegc3mQvv)
#
# Tag for the introduction
#
# ![image](https://drive.google.com/uc?id=1lZnqIqx64sOuaHPGq8sQL8nTemJjoCWM)

# %%
import logging
import scrapy
from scrapy.spiders import Rule, CrawlSpider
from scrapy.linkextractors import LinkExtractor

class NewsItem(scrapy.Item):
  # define the fields for your item here like:
  headline = scrapy.Field()
  intro = scrapy.Field()
  # url = scrapy.Field()

class NewsSpider(CrawlSpider):
  name = "bbcnews"
  allowed_domains = ["bbc.co.uk"]
  start_urls = ["http://www.bbc.co.uk/news/technology/",]
  custom_settings = {
      'LOG_LEVEL': logging.WARNING,
      'ITEM_PIPELINES': {'__main__.ConsoleWriterPipeline': 1} # Used for pipeline 1
      }
  rules = [Rule(LinkExtractor(allow=['/technology-\d+']), 'parse_story')]

  def parse_story(self, response):
    story = NewsItem()
    story['headline'] = response.xpath('//head/title/text()').get()
    story['intro'] = response.xpath('//p/b/text()').get()
    
    yield {
        "headline":story['headline'],
        "intro":story['intro']
        }

# %%
from scrapy.crawler import CrawlerProcess

hgw_crawler_process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

hgw_crawler_process.crawl(NewsSpider)
hgw_crawler_process.start()
# Out:
# 2022-05-11 06:05:11 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-05-11 06:05:11 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.4.0, Python 3.7.13 (default, Apr 24 2022, 01:04:09) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 3.0.3 3 May 2022), cryptography 37.0.2, Platform Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic
# 2022-05-11 06:05:11 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# {"headline": "Apple to discontinue the iPod after 21 years - BBC News", "intro": "Apple has announced it is discontinuing its music player, the iPod Touch, bringing to an end a device widely praised for revolutionising how people listen to music."}
#
# {"headline": "Influencers and followers need more protection, say MPs - BBC News", "intro": "MPs are calling for more protection for social media influencers and the children who follow them."}
#
# {"headline": "Twitter: X marks the spot for Elon Musk's growth plans - BBC News", "intro": "Elon Musk aims to increase Twitter's revenue fivefold to $26.4bn (\u00a321.4bn) by 2028, a presentation to prospective Twitter investors "}
#
# {"headline": "UK blames Russia for satellite internet hack at start of war - BBC News", "intro": "Russia was behind a cyber-attack targeting American commercial satellite internet company Viasat, UK and US intelligence suggests."}
#
# {"headline": "Prince Charles visits sustainable aviation laboratory - BBC News", "intro": null}
#
# {"headline": "BBC announces first ever Gaming Prom - BBC News", "intro": null}
#
# {"headline": "Nano ink solar cells allow tech to charge in any light - BBC News", "intro": "See more at "}
#
# {"headline": "\u00a35m Virtual Reality centre launches in Portsmouth - BBC News", "intro": "I'm in a large and colourful wooden-floored room. There's a man standing next to me, and a bird is at my feet. Suddenly both the man and the bird disappear. It sounds like the start of a surreal dream, and in a way it is, because none of it is real. I was actually standing on a high-tech digital stage at Portsmouth University."}
#
# {"headline": "Bill Gates on Elon Musk feud and Jeffrey Epstein meetings - BBC News", "intro": "In a wide-ranging interview with the BBC's Today programme, Bill Gates says conspiracy theories about him are \"crazy\" and that being shouted at in public is \"awful\". He also told the BBC's Mishal Husain that meeting Jeffrey Epstein was a \"mistake\" and talks about Elon Musk's recent public criticism of him."}
#
# {"headline": "Amazon targets review firms with legal action - BBC News", "intro": "Amazon is taking legal action against four companies it has accused of deliberately flooding its shopping platform with fake reviews."}
#
# {"headline": "UK government sets out plans to rein in Big Tech - BBC News", "intro": "Large tech companies such as Google and Facebook will have to abide by new competition rules in the UK or risk facing huge fines, the government said."}

# %% [markdown]
# ## General Crawl - Book Crawler
#
#
# A general crawler may have only one start URL, and typically two rules. It starts by added the start URL to its URL queue.
# it repeats the following until the URL queue is empty.
#  1. get a URL from the from the URL queue,
#      1. rule 1. when a target URL is loaded, extract it.
#      1. rule 2. when a non-target URL is loaded and add all (new) links in the page the URL queue.
#  1. remove the URL from the URL queue.

# %% [markdown]
# Goto http://books.toscrape.com.
#
# Extract each book title, price and stock
#
#
# ![image](https://drive.google.com/uc?id=1Z5pnlu47Wjc7Nl11EBRdM5E71QCPuuua)
#
#
#
#
# ```
# yield {
#             'title': response.css('.product_main h1::text').get(),
#             'price': response.css('.product_main p.price_color::text').re_first('£(.*)'),
#             'stock': int(
#                 ''.join(
#                     response.css('.product_main .instock.availability ::text').re('(\d+)')
#                 )
#             ),
#         }
# ```

# %%
import lxml.etree

import json
    
class ConsoleWriterPipeline(object):
    def open_spider(self, spider):
        None
    def close_spdier(self, spider):
        None
    
    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        print(line)
        return item
    
class JsonWriterPipeline(object):
    def open_spider(self, spider):
        self.file = open(data_dir_path+'bookresult.json', 'w')

    def close_spider(self, spider):
        print('JSON File Generated')
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import logging
import scrapy
from scrapy.spiders import CrawlSpider, Rule
from scrapy.linkextractors import LinkExtractor


class BooksCrawlSpider(CrawlSpider):
    name = 'books-crawlspider'
    allowed_domains = ['toscrape.com']
    start_urls = ['http://books.toscrape.com']
    custom_settings = {
      'LOG_LEVEL': logging.WARNING,
      'ITEM_PIPELINES': {'__main__.ConsoleWriterPipeline': 1}#, # Used for pipeline 1
      }
    rules = [
        Rule(
            LinkExtractor(allow=('/catalogue/page-\d+.html')),follow=True
        ),
        Rule(
             LinkExtractor(deny=('/category/books', '.com/index.html')),callback='parse_book_page',
            follow=True
        ),
    ]

    def parse_book_page(self, response):
        yield {
            'title': response.css('.product_main h1::text').get(),
            'price': response.css('.product_main p.price_color::text').re_first('£(.*)'),
            'stock': int(
                ''.join(
                    response.css('.product_main .instock.availability ::text').re('(\d+)')
                )
            ),
        }

# %%
#  uncomment me and run
from scrapy.crawler import CrawlerProcess

hgw_crawler_process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

hgw_crawler_process.crawl(BooksCrawlSpider)
hgw_crawler_process.start()
# Out:
# 2021-05-20 09:51:35 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: scrapybot)
# 2021-05-20 09:51:35 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.10 (default, May  3 2021, 02:48:31) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-5.4.109+-x86_64-with-Ubuntu-18.04-bionic
# 2021-05-20 09:51:35 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-05-20 09:51:35 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# {"title": "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", "price": "52.29", "stock": 19}
#
# {"title": "A Light in the Attic", "price": "51.77", "stock": 22}
#
# {"title": "Libertarianism for Beginners", "price": "51.33", "stock": 19}
#
# {"title": "Mesaerion: The Best Science Fiction Stories 1800-1849", "price": "37.59", "stock": 19}
#
# {"title": "Rip it Up and Start Again", "price": "35.02", "stock": 19}
#
# {"title": "Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991", "price": "57.25", "stock": 19}
#
# {"title": "It's Only the Himalayas", "price": "45.17", "stock": 19}
#
# {"title": "Olio", "price": "23.88", "stock": 19}
#
# {"title": "Set Me Free", "price": "17.46", "stock": 19}
#
# {"title": "Shakespeare's Sonnets", "price": "20.66", "stock": 19}
#
# {"title": "The Black Maria", "price": "52.15", "stock": 19}
#
# {"title": "The Dirty Little Secrets of Getting Your Dream Job", "price": "33.34", "stock": 19}
#
# {"title": "The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics", "price": "22.60", "stock": 19}
#
# {"title": "Starving Hearts (Triangular Trade Trilogy, #1)", "price": "13.99", "stock": 19}
#
# {"title": "The Requiem Red", "price": "22.65", "stock": 19}
#
# {"title": "The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull", "price": "17.93", "stock": 19}
#
# {"title": "Sapiens: A Brief History of Humankind", "price": "54.23", "stock": 20}
#
# {"title": "In Her Wake", "price": "12.84", "stock": 19}
#
# {"title": "Sharp Objects", "price": "47.82", "stock": 20}
#
# {"title": "Soumission", "price": "50.10", "stock": 20}
#
# {"title": "Tipping the Velvet", "price": "53.74", "stock": 20}
#
# {"title": "You can't bury them all: Poems", "price": "33.63", "stock": 17}
#
# {"title": "Penny Maybe", "price": "33.29", "stock": 18}
#
# {"title": "In a Dark, Dark Wood", "price": "19.63", "stock": 18}
#
# {"title": "Maude (1883-1993):She Grew Up with the country", "price": "18.02", "stock": 18}
#
# {"title": "Sophie's World", "price": "15.94", "stock": 18}
#
# {"title": "Behind Closed Doors", "price": "52.22", "stock": 18}
#
# {"title": "The Bear and the Piano", "price": "36.89", "stock": 18}
#
# {"title": "The Elephant Tree", "price": "23.82", "stock": 18}
#
# {"title": "The Five Love Languages: How to Express Heartfelt Commitment to Your Mate", "price": "31.05", "stock": 18}
#
# {"title": "Wall and Piece", "price": "44.18", "stock": 18}
#
# {"title": "The Four Agreements: A Practical Guide to Personal Freedom", "price": "17.66", "stock": 18}
#
# {"title": "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", "price": "22.50", "stock": 19}
#
# {"title": "Worlds Elsewhere: Journeys Around Shakespeare\u2019s Globe", "price": "40.30", "stock": 18}
#
# {"title": "Aladdin and His Wonderful Lamp", "price": "53.13", "stock": 19}
#
# {"title": "Chase Me (Paris Nights #2)", "price": "25.27", "stock": 19}
#
# {"title": "Birdsong: A Story in Pictures", "price": "54.64", "stock": 19}
#
# {"title": "Black Dust", "price": "34.53", "stock": 19}
#
# {"title": "Rework", "price": "44.88", "stock": 3}
#
# {"title": "Slow States of Collapse: Poems", "price": "57.31", "stock": 17}
#
# {"title": "Louisa: The Extraordinary Life of Mrs. Adams", "price": "16.85", "stock": 15}
#
# {"title": "Peak: Secrets from the New Science of Expertise", "price": "16.28", "stock": 5}
#
# {"title": "Benjamin Franklin: An American Life", "price": "48.19", "stock": 7}
#
# {"title": "The Faith of Christopher Hitchens: The Restless Soul of the World's Most Notorious Atheist", "price": "39.55", "stock": 7}
#
# {"title": "Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena", "price": "21.15", "stock": 11}
#
# {"title": "Mr. Mercedes (Bill Hodges Trilogy #1)", "price": "28.90", "stock": 14}
#
# {"title": "My Mrs. Brown", "price": "24.48", "stock": 14}
#
# {"title": "My Name Is Lucy Barton", "price": "41.56", "stock": 14}
#
# {"title": "I Am Pilgrim (Pilgrim #1)", "price": "10.60", "stock": 14}
#
# {"title": "Eligible (The Austen Project #4)", "price": "27.09", "stock": 14}
#
# {"title": "God: The Most Unpleasant Character in All Fiction", "price": "30.03", "stock": 14}
#
# {"title": "The Book of Mormon", "price": "24.57", "stock": 9}
#
# {"title": "A History of God: The 4,000-Year Quest of Judaism, Christianity, and Islam", "price": "27.62", "stock": 4}
#
# {"title": "This Is Your Brain on Music: The Science of a Human Obsession", "price": "38.40", "stock": 5}
#
# {"title": "Shtum", "price": "55.84", "stock": 14}
#
# {"title": "The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)", "price": "59.71", "stock": 4}
#
# {"title": "At The Existentialist Caf\u00e9: Freedom, Being, and apricot cocktails with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and others", "price": "29.93", "stock": 7}
#
# {"title": "You Are What You Love: The Spiritual Power of Habit", "price": "21.87", "stock": 15}
#
# {"title": "Critique of Pure Reason", "price": "20.75", "stock": 5}
#
# {"title": "Run, Spot, Run: The Ethics of Keeping Pets", "price": "20.02", "stock": 2}
#
# {"title": "The Nicomachean Ethics", "price": "36.34", "stock": 1}
#
# {"title": "The Nameless City (The Nameless City #1)", "price": "38.16", "stock": 16}
#
# {"title": "Sorting the Beef from the Bull: The Science of Food Fraud Forensics", "price": "44.74", "stock": 14}
#
# {"title": "The Fabric of the Cosmos: Space, Time, and the Texture of Reality", "price": "55.91", "stock": 9}
#
# {"title": "Tipping Point for Planet Earth: How Close Are We to the Edge?", "price": "37.55", "stock": 12}
#
# {"title": "Diary of a Citizen Scientist: Chasing Tiger Beetles and Other New Ways of Engaging the World", "price": "28.41", "stock": 8}
#
# {"title": "The Grand Design", "price": "13.76", "stock": 5}
#
# {"title": "The Origin of Species", "price": "10.01", "stock": 7}
#
# {"title": "The Wild Robot", "price": "56.07", "stock": 3}
#
# {"title": "The Thing About Jellyfish", "price": "48.77", "stock": 3}
#
# {"title": "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", "price": "37.97", "stock": 16}
#
# {"title": "The Time Keeper", "price": "27.88", "stock": 14}
#
# {"title": "The Day the Crayons Came Home (Crayons)", "price": "26.33", "stock": 3}
#
# {"title": "The Lonely Ones", "price": "43.59", "stock": 3}
#
# {"title": "The Testament of Mary", "price": "52.67", "stock": 14}
#
# {"title": "The First Hostage (J.B. Collins #2)", "price": "25.85", "stock": 14}
#
# {"title": "Finders Keepers (Bill Hodges Trilogy #2)", "price": "53.53", "stock": 15}
#
# {"title": "Maybe Something Beautiful: How Art Transformed a Neighborhood", "price": "22.54", "stock": 5}
#
# {"title": "Proofs of God: Classical Arguments from Tertullian to Barth", "price": "54.21", "stock": 8}
#
# {"title": "You (You #1)", "price": "43.61", "stock": 14}
#
# {"title": "The Stranger", "price": "17.44", "stock": 15}
#
# {"title": "The Guilty (Will Robie #4)", "price": "13.82", "stock": 14}
#
# {"title": "The 14th Colony (Cotton Malone #11)", "price": "39.24", "stock": 14}
#
# {"title": "Kierkegaard: A Christian Missionary to Christians", "price": "47.13", "stock": 8}
#
# {"title": "In the Country We Love: My Family Divided", "price": "22.00", "stock": 16}
#
# {"title": "Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)", "price": "53.90", "stock": 16}
#
# {"title": "Join", "price": "35.67", "stock": 16}
#
# {"title": "Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)", "price": "19.92", "stock": 16}
#
# {"title": "Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed", "price": "14.02", "stock": 16}
#
# {"title": "Layered: Baking, Building, and Styling Spectacular Cakes", "price": "40.11", "stock": 16}
#
# {"title": "Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)", "price": "46.91", "stock": 16}
#
# {"title": "Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)", "price": "45.61", "stock": 16}
#
# {"title": "Tuesday Nights in 1980", "price": "21.04", "stock": 15}
#
# {"title": "The Vacationers", "price": "42.15", "stock": 15}
#
# {"title": "The Regional Office Is Under Attack!", "price": "51.36", "stock": 15}
#
# {"title": "Shrunken Treasures: Literary Classics, Short, Sweet, and Silly", "price": "52.87", "stock": 7}
#
# {"title": "The Whale", "price": "35.96", "stock": 7}
#
# {"title": "Nap-a-Roo", "price": "25.08", "stock": 9}
#
# {"title": "Raymie Nightingale", "price": "34.41", "stock": 7}
#
# {"title": "Playing from the Heart", "price": "32.38", "stock": 7}
#
# {"title": "Luis Paints the World", "price": "53.95", "stock": 14}
#
# {"title": "Masks and Shadows", "price": "56.40", "stock": 16}
#
# {"title": "My Paris Kitchen: Recipes and Stories", "price": "33.37", "stock": 16}
#
# {"title": "Obsidian (Lux #1)", "price": "14.86", "stock": 16}
#
# {"title": "On a Midnight Clear", "price": "14.07", "stock": 16}
#
# {"title": "Online Marketing for Busy Authors: A Step-By-Step Guide", "price": "46.35", "stock": 16}
#
# {"title": "orange: The Complete Collection 1 (orange: The Complete Collection #1)", "price": "48.41", "stock": 16}
#
# {"title": "Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)", "price": "15.44", "stock": 16}
#
# {"title": "America's War for the Greater Middle East: A Military History", "price": "51.22", "stock": 5}
#
# {"title": "The Guns of August", "price": "14.54", "stock": 3}
#
# {"title": "The Secret (The Secret #1)", "price": "27.37", "stock": 15}
#
# {"title": "House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth", "price": "43.70", "stock": 3}
#
# {"title": "The Psychopath Test: A Journey Through the Madness Industry", "price": "36.00", "stock": 15}
#
# {"title": "The Kite Runner", "price": "41.82", "stock": 15}
#
# {"title": "The Girl on the Train", "price": "55.02", "stock": 15}
#
# {"title": "The Emerald Mystery", "price": "23.15", "stock": 15}
#
# {"title": "Little Red", "price": "13.47", "stock": 15}
#
# {"title": "Walt Disney's Alice in Wonderland", "price": "12.96", "stock": 14}
#
# {"title": "Rain Fish", "price": "23.57", "stock": 14}
#
# {"title": "Twenty Yawns", "price": "22.08", "stock": 14}
#
# {"title": "The Edge of Reason (Bridget Jones #2)", "price": "19.18", "stock": 1}
#
# {"title": "Once Was a Time", "price": "18.28", "stock": 14}
#
# {"title": "Bridget Jones's Diary (Bridget Jones #1)", "price": "29.82", "stock": 1}
#
# {"title": "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.", "price": "32.00", "stock": 15}
#
# {"title": "A New Earth: Awakening to Your Life's Purpose", "price": "55.65", "stock": 4}
#
# {"title": "Unreasonable Hope: Finding Faith in the God Who Brings Purpose to Your Pain", "price": "46.33", "stock": 7}
#
# {"title": "If I Gave You God's Phone Number....: Searching for Spirituality in America", "price": "20.91", "stock": 9}
#
# {"title": "Chasing Heaven: What Dying Taught Me About Living", "price": "37.80", "stock": 15}
#
# {"title": "The Mistake (Off-Campus #2)", "price": "43.29", "stock": 15}
#
# {"title": "Sugar Rush (Offensive Line #2)", "price": "24.42", "stock": 2}
#
# {"title": "The Matchmaker's Playbook (Wingmen Inc. #1)", "price": "55.85", "stock": 15}
#
# {"title": "The Hook Up (Game On #1)", "price": "36.29", "stock": 1}
#
# {"title": "A World of Flavor: Your Gluten Free Passport", "price": "42.95", "stock": 16}
#
# {"title": "Tracing Numbers on a Train", "price": "41.60", "stock": 15}
#
# {"title": "A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations", "price": "56.76", "stock": 16}
#
# {"title": "Bossypants", "price": "49.46", "stock": 16}
#
# {"title": "Thirteen Reasons Why", "price": "52.72", "stock": 15}
#
# {"title": "\"Most Blessed of the Patriarchs\": Thomas Jefferson and the Empire of the Imagination", "price": "44.48", "stock": 8}
#
# {"title": "The Rise and Fall of the Third Reich: A History of Nazi Germany", "price": "39.67", "stock": 6}
#
# {"title": "A Short History of Nearly Everything", "price": "52.40", "stock": 7}
#
# {"title": "Something Borrowed (Darcy & Rachel #1)", "price": "48.96", "stock": 3}
#
# {"title": "The Nanny Diaries (Nanny #1)", "price": "52.53", "stock": 3}
#
# {"title": "Something Blue (Darcy & Rachel #2)", "price": "54.62", "stock": 3}
#
# {"title": "I've Got Your Number", "price": "19.69", "stock": 3}
#
# {"title": "The Undomestic Goddess", "price": "45.75", "stock": 3}
#
# {"title": "Catherine the Great: Portrait of a Woman", "price": "58.55", "stock": 6}
#
# {"title": "The Devil Wears Prada (The Devil Wears Prada #1)", "price": "44.29", "stock": 3}
#
# {"title": "The Mathews Men: Seven Brothers and the War Against Hitler's U-boats", "price": "42.91", "stock": 5}
#
# {"title": "The Book of Basketball: The NBA According to The Sports Guy", "price": "44.84", "stock": 3}
#
# {"title": "Three Wishes (River of Time: California #1)", "price": "44.18", "stock": 1}
#
# {"title": "Do Androids Dream of Electric Sheep? (Blade Runner #1)", "price": "51.48", "stock": 3}
#
# {"title": "The Last Girl (The Dominion Trilogy #1)", "price": "36.26", "stock": 1}
#
# {"title": "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", "price": "34.96", "stock": 1}
#
# {"title": "Searching for Meaning in Gailana", "price": "38.73", "stock": 13}
#
# {"title": "The Star-Touched Queen", "price": "32.30", "stock": 12}
#
# {"title": "City of Glass (The Mortal Instruments #3)", "price": "56.02", "stock": 14}
#
# {"title": "Zealot: The Life and Times of Jesus of Nazareth", "price": "24.70", "stock": 14}
#
# {"title": "A Distant Mirror: The Calamitous 14th Century", "price": "14.58", "stock": 14}
#
# {"title": "A Shard of Ice (The Black Symphony Saga #1)", "price": "56.63", "stock": 9}
#
# {"title": "Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History", "price": "59.64", "stock": 15}
#
# {"title": "1491: New Revelations of the Americas Before Columbus", "price": "21.80", "stock": 14}
#
# {"title": "Brilliant Beacons: A History of the American Lighthouse", "price": "11.45", "stock": 8}
#
# {"title": "Friday Night Lights: A Town, a Team, and a Dream", "price": "51.22", "stock": 3}
#
# {"title": "King's Folly (The Kinsman Chronicles #1)", "price": "39.61", "stock": 7}
#
# {"title": "Grey (Fifty Shades #4)", "price": "48.49", "stock": 11}
#
# {"title": "Shopaholic Ties the Knot (Shopaholic #3)", "price": "48.39", "stock": 4}
#
# {"title": "Meternity", "price": "43.58", "stock": 7}
#
# {"title": "Some Women", "price": "13.73", "stock": 4}
#
# {"title": "Can You Keep a Secret?", "price": "21.94", "stock": 4}
#
# {"title": "Twenties Girl", "price": "42.80", "stock": 3}
#
# {"title": "Off Sides (Off #1)", "price": "39.45", "stock": 1}
#
# {"title": "Shameless", "price": "58.35", "stock": 1}
#
# {"title": "Hollow City (Miss Peregrine\u2019s Peculiar Children #2)", "price": "42.98", "stock": 15}
#
# {"title": "The Star-Touched Queen", "price": "46.02", "stock": 14}
#
# {"title": "The Hidden Oracle (The Trials of Apollo #1)", "price": "52.26", "stock": 14}
#
# {"title": "The Bane Chronicles (The Bane Chronicles #1-11)", "price": "44.73", "stock": 14}
#
# {"title": "Foundation (Foundation (Publication Order) #1)", "price": "32.42", "stock": 5}
#
# {"title": "Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)", "price": "37.51", "stock": 14}
#
# {"title": "Arena", "price": "21.36", "stock": 11}
#
# {"title": "Island of Dragons (Unwanteds #7)", "price": "29.65", "stock": 14}
#
# {"title": "The Stand", "price": "57.86", "stock": 3}
#
# {"title": "The Girl with All the Gifts", "price": "49.47", "stock": 3}
#
# {"title": "House of Leaves", "price": "54.89", "stock": 3}
#
# {"title": "The Restaurant at the End of the Universe (Hitchhiker's Guide to the Galaxy #2)", "price": "10.92", "stock": 3}
#
# {"title": "Ready Player One", "price": "19.07", "stock": 3}
#
# {"title": "Life, the Universe and Everything (Hitchhiker's Guide to the Galaxy #3)", "price": "33.26", "stock": 3}
#
# {"title": "Dune (Dune #1)", "price": "54.86", "stock": 3}
#
# {"title": "Logan Kade (Fallen Crest High #5.5)", "price": "13.12", "stock": 5}
#
# {"title": "The Perfect Play (Play by Play #1)", "price": "59.99", "stock": 4}
#
# {"title": "Dark Lover (Black Dagger Brotherhood #1)", "price": "12.87", "stock": 4}
#
# {"title": "Changing the Game (Play by Play #2)", "price": "13.38", "stock": 4}
#
# {"title": "I Had a Nice Time And Other Lies...: How to find love & sh*t like that", "price": "57.36", "stock": 15}
#
# {"title": "Will You Won't You Want Me?", "price": "13.86", "stock": 12}
#
# {"title": "Keep Me Posted", "price": "20.46", "stock": 11}
#
# {"title": "The Hiding Place", "price": "55.91", "stock": 5}
#
# {"title": "A Brush of Wings (Angels Walking #3)", "price": "55.51", "stock": 14}
#
# {"title": "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", "price": "43.30", "stock": 15}
#
# {"title": "Soft Apocalypse", "price": "26.12", "stock": 15}
#
# {"title": "Sleeping Giants (Themis Files #1)", "price": "48.74", "stock": 11}
#
# {"title": "The Project", "price": "10.65", "stock": 15}
#
# {"title": "Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)", "price": "28.09", "stock": 16}
#
# {"title": "Crown of Midnight (Throne of Glass #2)", "price": "43.29", "stock": 16}
#
# {"title": "Throne of Glass (Throne of Glass #1)", "price": "35.07", "stock": 15}
#
# {"title": "A Court of Thorns and Roses (A Court of Thorns and Roses #1)", "price": "52.37", "stock": 16}
#
# {"title": "Dracula the Un-Dead", "price": "35.63", "stock": 5}
#
# {"title": "Night Shift (Night Shift #1-20)", "price": "12.75", "stock": 4}
#
# {"title": "Misery", "price": "34.79", "stock": 4}
#
# {"title": "Needful Things", "price": "47.51", "stock": 4}
#
# {"title": "'Salem's Lot", "price": "49.56", "stock": 4}
#
# {"title": "It", "price": "25.01", "stock": 4}
#
# {"title": "The Glittering Court (The Glittering Court #1)", "price": "44.28", "stock": 15}
#
# {"title": "Rook", "price": "37.86", "stock": 13}
#
# {"title": "Code Name Verity (Code Name Verity #1)", "price": "22.13", "stock": 14}
#
# {"title": "More Than Music (Chasing the Dream #1)", "price": "37.61", "stock": 14}
#
# {"title": "Angels Walking (Angels Walking #1)", "price": "34.20", "stock": 14}
#
# {"title": "A People's History of the United States", "price": "40.79", "stock": 14}
#
# {"title": "Cell", "price": "20.29", "stock": 14}
#
# {"title": "A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer", "price": "56.48", "stock": 14}
#
# {"title": "Take Me Home Tonight (Rock Star Romance #3)", "price": "53.98", "stock": 11}
#
# {"title": "Dirty (Dive Bar #1)", "price": "40.83", "stock": 12}
#
# {"title": "A Gentleman's Position (Society of Gentlemen #3)", "price": "14.75", "stock": 11}
#
# {"title": "Off the Hook (Fishing for Trouble #1)", "price": "47.67", "stock": 11}
#
# {"title": "The Midnight Watch: A Novel of the Titanic and the Californian", "price": "26.20", "stock": 12}
#
# {"title": "Sit, Stay, Love", "price": "20.90", "stock": 7}
#
# {"title": "A Girl's Guide to Moving On (New Beginnings #2)", "price": "31.30", "stock": 5}
#
# {"title": "The White Cat and the Monk: A Retelling of the Poem \u201cPangur B\u00e1n\u201d", "price": "58.08", "stock": 15}
#
# {"title": "Settling the Score (The Summer Games #1)", "price": "44.91", "stock": 1}
#
# {"title": "Icing (Aces Hockey #2)", "price": "40.44", "stock": 1}
#
# {"title": "The Loney", "price": "23.40", "stock": 14}
#
# {"title": "Pet Sematary", "price": "10.56", "stock": 14}
#
# {"title": "Doctor Sleep (The Shining #2)", "price": "40.12", "stock": 14}
#
# {"title": "Psycho: Sanitarium (Psycho #1.5)", "price": "36.97", "stock": 12}
#
# {"title": "Can You Keep a Secret? (Fear Street Relaunch #4)", "price": "48.64", "stock": 12}
#
# {"title": "Red Dragon (Hannibal Lecter #1)", "price": "23.37", "stock": 5}
#
# {"title": "Patience", "price": "10.16", "stock": 16}
#
# {"title": "Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics", "price": "36.28", "stock": 16}
#
# {"title": "The Wedding Dress", "price": "24.12", "stock": 15}
#
# {"title": "Something More Than This", "price": "16.24", "stock": 15}
#
# {"title": "Doing It Over (Most Likely To #1)", "price": "35.61", "stock": 15}
#
# {"title": "Hold Your Breath (Search and Rescue #1)", "price": "28.82", "stock": 14}
#
# {"title": "The Wedding Pact (The O'Malleys #2)", "price": "32.61", "stock": 14}
#
# {"title": "Suddenly in Love (Lake Haven #1)", "price": "55.99", "stock": 15}
#
# {"title": "Shobu Samurai, Project Aryoku (#3)", "price": "29.06", "stock": 15}
#
# {"title": "Modern Romance", "price": "28.26", "stock": 15}
#
# {"title": "The Song of Achilles", "price": "37.40", "stock": 14}
#
# {"title": "Princess Between Worlds (Wide-Awake Princess #5)", "price": "13.34", "stock": 16}
#
# {"title": "The Immortal Life of Henrietta Lacks", "price": "40.67", "stock": 14}
#
# {"title": "The Dovekeepers", "price": "48.78", "stock": 14}
#
# {"title": "Pop Gun War, Volume 1: Gift", "price": "18.97", "stock": 16}
#
# {"title": "The White Queen (The Cousins' War #1)", "price": "25.91", "stock": 14}
#
# {"title": "Catching Jordan (Hundred Oaks)", "price": "50.83", "stock": 14}
#
# {"title": "Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)", "price": "58.14", "stock": 14}
#
# {"title": "Naked", "price": "31.69", "stock": 3}
#
# {"title": "When You Are Engulfed in Flames", "price": "30.89", "stock": 3}
#
# {"title": "The Epidemic (The Program 0.6)", "price": "14.44", "stock": 12}
#
# {"title": "Follow You Home", "price": "21.36", "stock": 15}
#
# {"title": "Lamb: The Gospel According to Biff, Christ's Childhood Pal", "price": "55.50", "stock": 3}
#
# {"title": "Holidays on Ice", "price": "51.07", "stock": 3}
#
# {"title": "Stars Above (The Lunar Chronicles #4.5)", "price": "48.05", "stock": 12}
#
# {"title": "Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine", "price": "57.36", "stock": 16}
#
# {"title": "Her Backup Boyfriend (The Sorensen Family #1)", "price": "33.97", "stock": 16}
#
# {"title": "First and First (Five Boroughs #3)", "price": "15.97", "stock": 16}
#
# {"title": "Fifty Shades Darker (Fifty Shades #2)", "price": "21.96", "stock": 16}
#
# {"title": "The Guernsey Literary and Potato Peel Pie Society", "price": "49.53", "stock": 3}
#
# {"title": "The Last Painting of Sara de Vos", "price": "55.55", "stock": 3}
#
# {"title": "The Red Tent", "price": "35.66", "stock": 3}
#
# {"title": "Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)", "price": "13.61", "stock": 16}
#
# {"title": "Girl in the Blue Coat", "price": "46.83", "stock": 3}
#
# {"title": "This Is Where It Ends", "price": "27.12", "stock": 14}
#
# {"title": "Until Friday Night (The Field Party #1)", "price": "46.31", "stock": 14}
#
# {"title": "My Kind of Crazy", "price": "40.36", "stock": 14}
#
# {"title": "Don't Get Caught", "price": "55.35", "stock": 14}
#
# {"title": "The Darkest Lie", "price": "35.35", "stock": 14}
#
# {"title": "Give It Back", "price": "18.32", "stock": 6}
#
# {"title": "Wild Swans", "price": "14.36", "stock": 14}
#
# {"title": "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction", "price": "25.98", "stock": 14}
#
# {"title": "The Long Haul (Diary of a Wimpy Kid #9)", "price": "44.07", "stock": 14}
#
# {"title": "Killing Floor (Jack Reacher #1)", "price": "31.49", "stock": 5}
#
# {"title": "Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened", "price": "14.75", "stock": 14}
#
# {"title": "Old School (Diary of a Wimpy Kid #10)", "price": "11.83", "stock": 14}
#
# {"title": "Toddlers Are A**holes: It's Not Your Fault", "price": "25.55", "stock": 7}
#
# {"title": "Dress Your Family in Corduroy and Denim", "price": "43.68", "stock": 9}
#
# {"title": "So You've Been Publicly Shamed", "price": "12.23", "stock": 15}
#
# {"title": "The Invention of Wings", "price": "37.34", "stock": 6}
#
# {"title": "The Constant Princess (The Tudor Court #1)", "price": "16.62", "stock": 7}
#
# {"title": "Girl With a Pearl Earring", "price": "26.77", "stock": 4}
#
# {"title": "World Without End (The Pillars of the Earth #2)", "price": "32.97", "stock": 5}
#
# {"title": "The Passion of Dolssa", "price": "28.32", "stock": 4}
#
# {"title": "Voyager (Outlander #3)", "price": "21.07", "stock": 3}
#
# {"title": "Love Is a Mix Tape (Music #1)", "price": "18.03", "stock": 14}
#
# {"title": "A Fierce and Subtle Poison", "price": "28.13", "stock": 16}
#
# {"title": "Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))", "price": "37.92", "stock": 16}
#
# {"title": "Burning", "price": "28.81", "stock": 16}
#
# {"title": "Call the Nurse: True Stories of a Country Nurse on a Scottish Isle", "price": "29.14", "stock": 16}
#
# {"title": "Camp Midnight", "price": "17.08", "stock": 16}
#
# {"title": "Codename Baboushka, Volume 1: The Conclave of Death", "price": "36.72", "stock": 16}
#
# {"title": "Everydata: The Misinformation Hidden in the Little Data You Consume Every Day", "price": "54.35", "stock": 16}
#
# {"title": "Danganronpa Volume 1", "price": "51.99", "stock": 16}
#
# {"title": "Lust & Wonder", "price": "11.87", "stock": 3}
#
# {"title": "Me Talk Pretty One Day", "price": "57.60", "stock": 3}
#
# {"title": "Life Without a Recipe", "price": "59.04", "stock": 3}
#
# {"title": "A Heartbreaking Work of Staggering Genius", "price": "54.29", "stock": 3}
#
# {"title": "Catastrophic Happiness: Finding Joy in Childhood's Messy Years", "price": "37.35", "stock": 3}
#
# {"title": "Fifty Shades Freed (Fifty Shades #3)", "price": "15.36", "stock": 3}
#
# {"title": "Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton", "price": "29.69", "stock": 16}
#
# {"title": "Giant Days, Vol. 2 (Giant Days #5-8)", "price": "22.11", "stock": 16}
#
# {"title": "Mrs. Houdini", "price": "30.25", "stock": 15}
#
# {"title": "The Marriage of Opposites", "price": "28.08", "stock": 14}
#
# {"title": "Love, Lies and Spies", "price": "20.55", "stock": 12}
#
# {"title": "Glory over Everything: Beyond The Kitchen House", "price": "45.84", "stock": 14}
#
# {"title": "A Paris Apartment", "price": "39.01", "stock": 12}
#
# {"title": "Lilac Girls", "price": "17.28", "stock": 11}
#
# {"title": "The Power of Now: A Guide to Spiritual Enlightenment", "price": "43.54", "stock": 15}
#
# {"title": "Algorithms to Live By: The Computer Science of Human Decisions", "price": "30.81", "stock": 16}
#
# {"title": "The Secret Healer", "price": "34.56", "stock": 1}
#
# {"title": "Between Shades of Gray", "price": "20.79", "stock": 3}
#
# {"title": "While You Were Mine", "price": "41.32", "stock": 1}
#
# {"title": "Starlark", "price": "25.83", "stock": 1}
#
# {"title": "Lost Among the Living", "price": "27.70", "stock": 1}
#
# {"title": "A Spy's Devotion (The Regency Spies of London #1)", "price": "16.97", "stock": 1}
#
# {"title": "The Omnivore's Dilemma: A Natural History of Four Meals", "price": "38.21", "stock": 15}
#
# {"title": "The Genius of Birds", "price": "17.24", "stock": 15}
#
# {"title": "Playing with Fire", "price": "13.71", "stock": 11}
#
# {"title": "8 Keys to Mental Health Through Exercise", "price": "31.04", "stock": 3}
#
# {"title": "The Widow", "price": "27.26", "stock": 11}
#
# {"title": "What Happened on Beale Street (Secrets of the South Mysteries #2)", "price": "25.37", "stock": 7}
#
# {"title": "Boar Island (Anna Pigeon #19)", "price": "59.48", "stock": 12}
#
# {"title": "The Bachelor Girl's Guide to Murder (Herringford and Watts Mysteries #1)", "price": "52.30", "stock": 7}
#
# {"title": "The Argonauts", "price": "10.93", "stock": 15}
#
# {"title": "Delivering the Truth (Quaker Midwife Mystery #1)", "price": "20.89", "stock": 7}
#
# {"title": "M Train", "price": "27.18", "stock": 11}
#
# {"title": "The House by the Lake", "price": "36.95", "stock": 15}
#
# {"title": "A Flight of Arrows (The Pathfinders #2)", "price": "55.53", "stock": 16}
#
# {"title": "Approval Junkie: Adventures in Caring Too Much", "price": "58.81", "stock": 5}
#
# {"title": "Lab Girl", "price": "40.85", "stock": 11}
#
# {"title": "Running with Scissors", "price": "12.91", "stock": 3}
#
# {"title": "How to Be Miserable: 40 Strategies You Already Use", "price": "46.03", "stock": 16}
#
# {"title": "The Artist's Way: A Spiritual Path to Higher Creativity", "price": "38.49", "stock": 15}
#
# {"title": "The Girl In The Ice (DCI Erika Foster #1)", "price": "15.85", "stock": 1}
#
# {"title": "Career of Evil (Cormoran Strike #3)", "price": "24.72", "stock": 3}
#
# {"title": "The Girl You Lost", "price": "12.29", "stock": 1}
#
# {"title": "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", "price": "57.70", "stock": 1}
#
# {"title": "I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)", "price": "29.17", "stock": 16}
#
# {"title": "1st to Die (Women's Murder Club #1)", "price": "53.98", "stock": 1}
#
# {"title": "Blood Defense (Samantha Brinkman #1)", "price": "20.30", "stock": 1}
#
# {"title": "I am a Hero Omnibus Volume 1", "price": "54.63", "stock": 16}
#
# {"title": "The Golden Condom: And Other Essays on Love Lost and Found", "price": "39.43", "stock": 12}
#
# {"title": "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle", "price": "56.27", "stock": 11}
#
# {"title": "An Unquiet Mind: A Memoir of Moods and Madness", "price": "21.30", "stock": 6}
#
# {"title": "Thinking, Fast and Slow", "price": "21.14", "stock": 3}
#
# {"title": "The Lucifer Effect: Understanding How Good People Turn Evil", "price": "10.40", "stock": 14}
#
# {"title": "Civilization and Its Discontents", "price": "59.95", "stock": 3}
#
# {"title": "Murder at the 42nd Street Library (Raymond Ambler #1)", "price": "54.36", "stock": 12}
#
# {"title": "Poisonous (Max Revere Novels #3)", "price": "26.80", "stock": 12}
#
# {"title": "A Time of Torment (Charlie Parker #14)", "price": "48.35", "stock": 14}
#
# {"title": "A Study in Scarlet (Sherlock Holmes #1)", "price": "16.73", "stock": 14}
#
# {"title": "Scarlett Epstein Hates It Here", "price": "43.55", "stock": 15}
#
# {"title": "Nightingale, Sing", "price": "38.28", "stock": 15}
#
# {"title": "Hide Away (Eve Duncan #20)", "price": "11.84", "stock": 12}
#
# {"title": "Most Wanted", "price": "35.28", "stock": 12}
#
# {"title": "Library of Souls (Miss Peregrine\u2019s Peculiar Children #3)", "price": "48.56", "stock": 15}
#
# {"title": "The Mysterious Affair at Styles (Hercule Poirot #1)", "price": "24.80", "stock": 6}
#
# {"title": "Extreme Prey (Lucas Davenport #26)", "price": "25.40", "stock": 3}
#
# {"title": "Frostbite (Vampire Academy #2)", "price": "29.99", "stock": 15}
#
# {"title": "In the Woods (Dublin Murder Squad #1)", "price": "38.38", "stock": 6}
#
# {"title": "The Silkworm (Cormoran Strike #2)", "price": "23.05", "stock": 3}
#
# {"title": "The Cuckoo's Calling (Cormoran Strike #1)", "price": "19.21", "stock": 3}
#
# {"title": "The Exiled", "price": "43.45", "stock": 3}
#
# {"title": "Please Kill Me: The Uncensored Oral History of Punk", "price": "31.19", "stock": 8}
#
# {"title": "The Murder of Roger Ackroyd (Hercule Poirot #4)", "price": "44.10", "stock": 15}
#
# {"title": "That Darkness (Gardiner and Renner #1)", "price": "13.92", "stock": 14}
#
# {"title": "The New Drawing on the Right Side of the Brain", "price": "43.02", "stock": 8}
#
# {"title": "Art and Fear: Observations on the Perils (and Rewards) of Artmaking", "price": "48.63", "stock": 9}
#
# {"title": "Tastes Like Fear (DI Marnie Rome #3)", "price": "10.69", "stock": 14}
#
# {"title": "The Last Mile (Amos Decker #2)", "price": "54.21", "stock": 14}
#
# {"title": "History of Beauty", "price": "10.29", "stock": 8}
#
# {"title": "The Story of Art", "price": "41.14", "stock": 7}
#
# {"title": "Chronicles, Vol. 1", "price": "52.60", "stock": 7}
#
# {"title": "Ways of Seeing", "price": "39.51", "stock": 1}
#
# {"title": "A Murder in Time", "price": "16.64", "stock": 16}
#
# {"title": "Kill 'Em and Leave: Searching for James Brown and the American Soul", "price": "45.05", "stock": 8}
#
# {"title": "The Art Book", "price": "32.34", "stock": 7}
#
# {"title": "Still Life with Bread Crumbs", "price": "26.41", "stock": 14}
#
# {"title": "Take Me with You", "price": "45.21", "stock": 14}
#
# {"title": "The Art and Science of Low Carbohydrate Living", "price": "52.98", "stock": 9}
#
# {"title": "Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond", "price": "52.65", "stock": 14}
#
# {"title": "Equal Is Unfair: America's Misguided Fight Against Income Inequality", "price": "56.86", "stock": 12}
#
# {"title": "Amid the Chaos", "price": "36.58", "stock": 15}
#
# {"title": "Dark Notes", "price": "19.19", "stock": 15}
#
# {"title": "The Long Shadow of Small Ghosts: Murder and Memory in an American City", "price": "10.97", "stock": 15}
#
# {"title": "The Third Wave: An Entrepreneur\u2019s Vision of the Future", "price": "12.61", "stock": 15}
#
# {"title": "(Un)Qualified: How God Uses Broken People to Do Big Things", "price": "54.00", "stock": 16}
#
# {"title": "Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)", "price": "50.40", "stock": 16}
#
# {"title": "Saga, Volume 5 (Saga (Collected Editions) #5)", "price": "51.04", "stock": 16}
#
# {"title": "Feathers: Displays of Brilliant Plumage", "price": "49.05", "stock": 14}
#
# {"title": "Saga, Volume 6 (Saga (Collected Editions) #6)", "price": "25.02", "stock": 16}
#
# {"title": "Reskilling America: Learning to Labor in the Twenty-First Century", "price": "19.83", "stock": 16}
#
# {"title": "Security", "price": "39.25", "stock": 16}
#
# {"title": "Soul Reader", "price": "39.58", "stock": 16}
#
# {"title": "Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up", "price": "41.83", "stock": 16}
#
# {"title": "The Shadow Hero (The Shadow Hero)", "price": "33.14", "stock": 15}
#
# {"title": "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", "price": "32.24", "stock": 16}
#
# {"title": "The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life", "price": "49.05", "stock": 16}
#
# {"title": "The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind", "price": "19.73", "stock": 16}
#
# {"title": "The Art Forger", "price": "40.76", "stock": 16}
#
# {"title": "The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First", "price": "41.25", "stock": 15}
#
# {"title": "The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking", "price": "37.60", "stock": 15}
#
# {"title": "Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress", "price": "52.15", "stock": 14}
#
# {"title": "You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life", "price": "12.08", "stock": 7}
#
# {"title": "How to Stop Worrying and Start Living", "price": "46.49", "stock": 6}
#
# {"title": "Redeeming Love", "price": "20.47", "stock": 15}
#
# {"title": "All the Light We Cannot See", "price": "29.87", "stock": 14}
#
# {"title": "The Girl You Left Behind (The Girl You Left Behind #1)", "price": "15.79", "stock": 6}
#
# {"title": "Close to You", "price": "49.46", "stock": 15}
#
# {"title": "Shadows of the Past (Logan Point #1)", "price": "39.67", "stock": 8}
#
# {"title": "Counted With the Stars (Out from Egypt #1)", "price": "17.97", "stock": 7}
#
# {"title": "Silence in the Dark (Logan Point #4)", "price": "58.33", "stock": 8}
#
# {"title": "If I Run (If I Run #1)", "price": "49.97", "stock": 3}
#
# {"title": "Like Never Before (Walker Family #2)", "price": "28.77", "stock": 7}
#
# {"title": "Suzie Snowflake: One beautiful flake (a self-esteem story)", "price": "54.81", "stock": 9}
#
# {"title": "The Grownup", "price": "35.88", "stock": 8}
#
# {"title": "10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!", "price": "49.71", "stock": 10}
#
# {"title": "Eat Fat, Get Thin", "price": "54.07", "stock": 14}
#
# {"title": "The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us", "price": "37.34", "stock": 15}
#
# {"title": "Crazy Love: Overwhelmed by a Relentless God", "price": "47.72", "stock": 14}
#
# {"title": "Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality", "price": "25.77", "stock": 7}
#
# {"title": "The Electric Pencil: Drawings from Inside State Hospital No. 3", "price": "56.06", "stock": 16}
#
# {"title": "The Death of Humanity: and the Case for Life", "price": "58.11", "stock": 16}
#
# {"title": "The Gutsy Girl: Escapades for Your Life of Epic Adventure", "price": "37.13", "stock": 16}
#
# {"title": "The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer", "price": "20.59", "stock": 16}
#
# {"title": "Everyday Italian: 125 Simple and Delicious Recipes", "price": "20.10", "stock": 12}
#
# {"title": "A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More", "price": "38.77", "stock": 12}
#
# {"title": "Cravings: Recipes for What You Want to Eat", "price": "20.50", "stock": 11}
#
# {"title": "32 Yolks", "price": "53.63", "stock": 8}
#
# {"title": "Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories", "price": "11.38", "stock": 7}
#
# {"title": "The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York", "price": "12.34", "stock": 9}
#
# {"title": "Night Sky with Exit Wounds", "price": "41.05", "stock": 15}
#
# {"title": "Poems That Make Grown Women Cry", "price": "14.19", "stock": 15}
#
# {"title": "Romero and Juliet: A Tragic Tale of Love and Zombies", "price": "36.94", "stock": 15}
#
# {"title": "Secrets and Lace (Fatal Hearts #1)", "price": "20.27", "stock": 15}
#
# {"title": "Shoe Dog: A Memoir by the Creator of NIKE", "price": "23.99", "stock": 15}
#
# {"title": "Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form", "price": "41.06", "stock": 15}
#
# {"title": "The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job", "price": "27.55", "stock": 15}
#
# {"title": "The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy", "price": "23.89", "stock": 16}
#
# {"title": "The Art of War", "price": "33.34", "stock": 15}
#
# {"title": "The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing", "price": "16.77", "stock": 16}
#
# {"title": "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", "price": "42.96", "stock": 16}
#
# {"title": "The Art of Startup Fundraising", "price": "21.00", "stock": 11}
#
# {"title": "The Murder That Never Was (Forensic Instincts #5)", "price": "54.11", "stock": 16}
#
# {"title": "Born for This: How to Find the Work You Were Meant to Do", "price": "21.59", "stock": 11}
#
# {"title": "Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two", "price": "43.14", "stock": 12}
#
# {"title": "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It", "price": "36.91", "stock": 8}
#
# {"title": "Rich Dad, Poor Dad", "price": "51.74", "stock": 7}
#
# {"title": "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes", "price": "19.55", "stock": 14}
#
# {"title": "The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth", "price": "28.77", "stock": 14}
#
# {"title": "Barefoot Contessa Back to Basics", "price": "28.01", "stock": 14}
#
# {"title": "Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals", "price": "42.16", "stock": 15}
#
# {"title": "My Kitchen Year: 136 Recipes That Saved My Life", "price": "11.53", "stock": 13}
#
# {"title": "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", "price": "50.62", "stock": 14}
#
# {"title": "Drive: The Surprising Truth About What Motivates Us", "price": "34.95", "stock": 15}
#
# {"title": "Done Rubbed Out (Reightman & Bailey #1)", "price": "37.72", "stock": 15}
#
# {"title": "Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life", "price": "51.75", "stock": 14}
#
# {"title": "Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years", "price": "15.06", "stock": 14}
#
# {"title": "Brain on Fire: My Month of Madness", "price": "49.32", "stock": 14}
#
# {"title": "13 Hours: The Inside Account of What Really Happened In Benghazi", "price": "27.06", "stock": 13}
#
# {"title": "Buying In: The Secret Dialogue Between What We Buy and Who We Are", "price": "37.80", "stock": 14}
#
# {"title": "Abstract City", "price": "56.37", "stock": 14}
#
# {"title": "Eureka Trivia 6.0", "price": "54.59", "stock": 15}
#
# {"title": "Fables, Vol. 1: Legends in Exile (Fables #1)", "price": "41.62", "stock": 15}
#
# {"title": "First Steps for New Christians (Print Edition)", "price": "29.00", "stock": 15}
#
# {"title": "Made to Stick: Why Some Ideas Survive and Others Die", "price": "38.85", "stock": 14}
#
# {"title": "Large Print Heart of the Pride", "price": "19.15", "stock": 15}
#
# {"title": "Full Moon over Noah\u2019s Ark: An Odyssey to Mount Ararat and Beyond", "price": "49.43", "stock": 15}
#
# {"title": "The Lean Startup: How Today's Entrepreneurs Use Continuous Innovation to Create Radically Successful Businesses", "price": "33.92", "stock": 3}
#
# {"title": "Grumbles", "price": "22.16", "stock": 15}
#
# {"title": "Meditations", "price": "25.89", "stock": 1}
#
# {"title": "Miss Peregrine\u2019s Home for Peculiar Children (Miss Peregrine\u2019s Peculiar Children #1)", "price": "10.76", "stock": 15}
#
# {"title": "Amatus", "price": "50.54", "stock": 15}
#
# {"title": "Amy Meets the Saints and Sages", "price": "18.46", "stock": 15}
#
# {"title": "Anonymous", "price": "46.82", "stock": 15}
#
# {"title": "Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)", "price": "37.34", "stock": 14}
#
# {"title": "Ayumi's Violin", "price": "15.48", "stock": 15}
#
# {"title": "Agnostic: A Spirited Manifesto", "price": "12.51", "stock": 15}
#
# {"title": "Batman: The Long Halloween (Batman)", "price": "36.50", "stock": 15}
#
# {"title": "Batman: The Dark Knight Returns (Batman)", "price": "15.38", "stock": 15}
#
# {"title": "Looking for Lovely: Collecting the Moments that Matter", "price": "29.14", "stock": 14}
#
# {"title": "Hamilton: The Revolution", "price": "58.79", "stock": 14}
#
# {"title": "Swell: A Year of Waves", "price": "45.58", "stock": 14}
#
# {"title": "The Bad-Ass Librarians of Timbuktu: And Their Race to Save the World\u2019s Most Precious Manuscripts", "price": "15.77", "stock": 14}
#
# {"title": "No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon", "price": "21.95", "stock": 14}
#
# {"title": "Let It Out: A Journey Through Journaling", "price": "26.79", "stock": 14}
#
# {"title": "Beauty Restored (Riley Family Legacy Novellas #3)", "price": "11.11", "stock": 15}
#
# {"title": "Becoming Wise: An Inquiry into the Mystery and Art of Living", "price": "27.43", "stock": 15}
#
# {"title": "Beyond Good and Evil", "price": "43.38", "stock": 1}
#
# {"title": "Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead", "price": "19.43", "stock": 15}
#
# {"title": "Big Magic: Creative Living Beyond Fear", "price": "30.80", "stock": 15}
#
# {"title": "Far From True (Promise Falls Trilogy #2)", "price": "34.93", "stock": 4}
#
# {"title": "Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors", "price": "12.36", "stock": 4}
#
# {"title": "The Travelers", "price": "15.77", "stock": 3}
#
# {"title": "Someone Like You (The Harrisons #2)", "price": "52.79", "stock": 14}
#
# {"title": "We Are All Completely Beside Ourselves", "price": "24.04", "stock": 3}
#
# {"title": "Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)", "price": "52.88", "stock": 2}
#
# {"title": "Matilda", "price": "28.34", "stock": 1}
#
# {"title": "Charlie and the Chocolate Factory (Charlie Bucket #1)", "price": "22.85", "stock": 1}
#
# {"title": "Booked", "price": "17.49", "stock": 5}
#
# {"title": "Leave This Song Behind: Teen Poetry at Its Best", "price": "51.17", "stock": 7}
#
# {"title": "The Collected Poems of W.B. Yeats (The Collected Works of W.B. Yeats #1)", "price": "15.42", "stock": 6}
#
# {"title": "The Crossover", "price": "38.77", "stock": 5}
#
# {"title": "Are We There Yet?", "price": "10.66", "stock": 3}
#
# {"title": "Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity", "price": "38.20", "stock": 14}
#
# {"title": "The Year of Magical Thinking", "price": "43.04", "stock": 14}
#
# {"title": "What's It Like in Space?: Stories from Astronauts Who've Been There", "price": "19.60", "stock": 14}
#
# {"title": "Vampire Knight, Vol. 1 (Vampire Knight #1)", "price": "15.40", "stock": 1}
#
# {"title": "Twenty Love Poems and a Song of Despair", "price": "30.95", "stock": 1}
#
# {"title": "The Bhagavad Gita", "price": "57.49", "stock": 1}
#
# {"title": "The Literature Book (Big Ideas Simply Explained)", "price": "17.43", "stock": 14}
#
# {"title": "Counting Thyme", "price": "10.62", "stock": 3}
#
# {"title": "Green Eggs and Ham (Beginner Books B-16)", "price": "10.79", "stock": 3}
#
# {"title": "The Story of Hong Gildong", "price": "43.19", "stock": 1}
#
# {"title": "The Little Prince", "price": "45.42", "stock": 1}
#
# {"title": "Choosing Our Religion: The Spiritual Lives of America's Nones", "price": "28.42", "stock": 1}
#
# {"title": "Sense and Sensibility", "price": "37.46", "stock": 1}
#
# {"title": "Of Mice and Men", "price": "47.11", "stock": 1}
#
# {"title": "The Cat in the Hat (Beginner Books B-1)", "price": "16.26", "stock": 3}
#
# {"title": "salt.", "price": "46.78", "stock": 14}
#
# {"title": "Quarter Life Poetry: Poems for the Young, Broke and Hangry", "price": "50.89", "stock": 14}
#
# {"title": "Out of Print: City Lights Spotlight No. 14", "price": "53.64", "stock": 8}
#
# {"title": "Howl and Other Poems", "price": "40.45", "stock": 8}
#
# {"title": "Les Fleurs du Mal", "price": "29.04", "stock": 8}
#
# {"title": "Red: The True Story of Red Riding Hood", "price": "28.54", "stock": 3}
#
# {"title": "Horrible Bear!", "price": "37.52", "stock": 3}
#
# {"title": "Me Before You (Me Before You #1)", "price": "19.02", "stock": 6}
#
# {"title": "The Rosie Project (Don Tillman #1)", "price": "54.04", "stock": 14}
#
# {"title": "The Wright Brothers", "price": "56.80", "stock": 14}
#
# {"title": "The Songs of the Gods", "price": "44.48", "stock": 14}
#
# {"title": "V for Vendetta (V for Vendetta Complete)", "price": "37.10", "stock": 14}
#
# {"title": "Through the Woods", "price": "25.38", "stock": 14}
#
# {"title": "Unbroken: A World War II Story of Survival, Resilience, and Redemption", "price": "45.95", "stock": 14}
#
# {"title": "We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)", "price": "53.90", "stock": 14}
#
# {"title": "Animal Farm", "price": "57.22", "stock": 4}
#
# {"title": "The Picture of Dorian Gray", "price": "29.70", "stock": 3}
#
# {"title": "The Complete Stories and Poems (The Works of Edgar Allan Poe [Cameo Edition])", "price": "26.78", "stock": 3}
#
# {"title": "Beowulf", "price": "38.35", "stock": 3}
#
# {"title": "And Then There Were None", "price": "35.01", "stock": 3}
#
# {"title": "Wuthering Heights", "price": "17.73", "stock": 3}
#
# {"title": "Memoirs of a Geisha", "price": "49.67", "stock": 7}
#
# {"title": "Sister Dear", "price": "40.20", "stock": 7}
#
# {"title": "Emma", "price": "32.93", "stock": 1}
#
# {"title": "Hystopia: A Novel", "price": "21.96", "stock": 8}
#
# {"title": "Miller's Valley", "price": "58.54", "stock": 8}
#
# {"title": "The Bourne Identity (Jason Bourne #1)", "price": "42.78", "stock": 7}
#
# {"title": "Alice in Wonderland (Alice's Adventures in Wonderland #1)", "price": "55.53", "stock": 1}
#
# {"title": "The Power of Habit: Why We Do What We Do in Life and Business", "price": "16.88", "stock": 14}
#
# ...
#
# {"title": "The God Delusion", "price": "46.85", "stock": 6}
#
# {"title": "Lola and the Boy Next Door (Anna and the French Kiss #2)", "price": "23.63", "stock": 5}
#
# {"title": "Kill the Boy Band", "price": "15.52", "stock": 5}
#
# {"title": "The Glass Castle", "price": "16.24", "stock": 7}
#
# {"title": "Isla and the Happily Ever After (Anna and the French Kiss #3)", "price": "48.13", "stock": 5}
#
# {"title": "The Drowning Girls", "price": "35.67", "stock": 7}
#
# {"title": "Team of Rivals: The Political Genius of Abraham Lincoln", "price": "20.12", "stock": 7}
#
# {"title": "Tell Me Three Things", "price": "41.81", "stock": 5}
#
# {"title": "Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)", "price": "45.24", "stock": 1}
#
# {"title": "Giant Days, Vol. 1 (Giant Days #1-4)", "price": "56.76", "stock": 1}
#
# {"title": "Fruits Basket, Vol. 1 (Fruits Basket #1)", "price": "40.28", "stock": 1}
#
# {"title": "Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)", "price": "34.65", "stock": 1}
#
# {"title": "The Darkest Corners", "price": "11.33", "stock": 5}
#
# {"title": "Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)", "price": "57.06", "stock": 1}
#
# {"title": "When I'm Gone", "price": "51.96", "stock": 1}
#
# {"title": "An Abundance of Katherines", "price": "10.00", "stock": 5}
#
# {"title": "South of Sunshine", "price": "28.93", "stock": 8}
#
# {"title": "Being Mortal: Medicine and What Matters in the End", "price": "55.06", "stock": 8}
#
# {"title": "The Martian (The Martian #1)", "price": "41.39", "stock": 8}
#
# {"title": "23 Degrees South: A Tropical Tale of Changing Whether...", "price": "35.79", "stock": 9}
#
# {"title": "Watchmen", "price": "58.05", "stock": 9}
#
# {"title": "Tell the Wolves I'm Home", "price": "50.96", "stock": 6}
#
# {"title": "The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)", "price": "43.62", "stock": 8}
#
# {"title": "A Hero's Curse (The Unseen Chronicles #1)", "price": "50.49", "stock": 9}
#
# {"title": "The Year of Living Biblically: One Man's Humble Quest to Follow the Bible as Literally as Possible", "price": "34.72", "stock": 7}
#
# {"title": "Wildlife of New York: A Five-Borough Coloring Book", "price": "22.14", "stock": 7}
#
# {"title": "Death by Leisure: A Cautionary Tale", "price": "37.51", "stock": 8}
#
# {"title": "Paper Girls, Vol. 1 (Paper Girls #1-5)", "price": "21.71", "stock": 1}
#
# {"title": "Skip Beat!, Vol. 01 (Skip Beat! #1)", "price": "42.12", "stock": 1}
#
# {"title": "Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)", "price": "29.87", "stock": 1}
#
# {"title": "Saga, Volume 1 (Saga (Collected Editions) #1)", "price": "28.48", "stock": 1}
#
# {"title": "Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)", "price": "46.96", "stock": 1}
#
# {"title": "Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)", "price": "39.39", "stock": 1}
#
# {"title": "Nightstruck: A Novel", "price": "50.35", "stock": 7}
#
# {"title": "Ender's Game (The Ender Quintet #1)", "price": "43.64", "stock": 8}
#
# {"title": "Future Shock (Future Shock #1)", "price": "55.65", "stock": 8}
#
# {"title": "Will Grayson, Will Grayson (Will Grayson, Will Grayson)", "price": "47.31", "stock": 5}
#
# {"title": "Where She Went (If I Stay #2)", "price": "41.73", "stock": 5}
#
# {"title": "Two Summers", "price": "14.64", "stock": 5}
#
# {"title": "Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back", "price": "52.86", "stock": 8}
#
# {"title": "The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)", "price": "54.12", "stock": 1}
#
# {"title": "The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)", "price": "36.52", "stock": 1}
#
# {"title": "The Haters", "price": "27.89", "stock": 1}
#
# {"title": "The Art of Not Breathing", "price": "40.83", "stock": 1}
#
# {"title": "Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)", "price": "18.51", "stock": 1}
#
# {"title": "The Complete Maus (Maus #1-2)", "price": "10.64", "stock": 1}
#
# {"title": "The Great Gatsby", "price": "36.05", "stock": 7}
#
# {"title": "Steal Like an Artist: 10 Things Nobody Told You About Being Creative", "price": "20.90", "stock": 7}
#
# {"title": "The Good Girl", "price": "49.03", "stock": 7}
#
# {"title": "The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change", "price": "33.17", "stock": 7}
#
# {"title": "Girl Online On Tour (Girl Online #2)", "price": "53.47", "stock": 2}
#
# {"title": "New Moon (Twilight #2)", "price": "12.86", "stock": 2}
#
# {"title": "Annie on My Mind", "price": "36.83", "stock": 3}
#
# {"title": "Golden (Heart of Dread #3)", "price": "42.21", "stock": 3}
#
# {"title": "Cinder (The Lunar Chronicles #1)", "price": "26.09", "stock": 3}
#
# {"title": "Boy Meets Boy", "price": "21.12", "stock": 3}
#
# {"title": "Brave Enough", "price": "51.32", "stock": 3}
#
# {"title": "Disrupted: My Misadventure in the Start-Up Bubble", "price": "15.28", "stock": 3}
#
# {"title": "Gratitude", "price": "26.66", "stock": 3}
#
# {"title": "I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban", "price": "28.88", "stock": 3}
#
# {"title": "Blink: The Power of Thinking Without Thinking", "price": "21.74", "stock": 3}
#
# {"title": "Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen", "price": "27.35", "stock": 3}
#
# {"title": "Life of Pi", "price": "13.22", "stock": 7}
#
# {"title": "Lady Renegades (Rebel Belle #3)", "price": "53.04", "stock": 3}
#
# {"title": "Two Boys Kissing", "price": "32.74", "stock": 3}
#
# {"title": "Scarlet (The Lunar Chronicles #2)", "price": "14.57", "stock": 3}
#
# {"title": "Legend (Legend #1)", "price": "43.69", "stock": 3}
#
# {"title": "The New Guy (and Other Senior Year Distractions)", "price": "44.92", "stock": 3}
#
# {"title": "The Land of 10,000 Madonnas", "price": "29.64", "stock": 3}
#
# {"title": "Letter to a Christian Nation", "price": "22.20", "stock": 3}
#
# {"title": "It's Never Too Late to Begin Again: Discovering Creativity and Meaning at Midlife and Beyond", "price": "42.38", "stock": 3}
#
# {"title": "Into the Wild", "price": "56.70", "stock": 3}
#
# {"title": "In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin", "price": "28.85", "stock": 3}
#
# {"title": "Let's Pretend This Never Happened: A Mostly True Memoir", "price": "45.11", "stock": 3}
#
# {"title": "The Fellowship of the Ring (The Lord of the Rings #1)", "price": "10.27", "stock": 6}
#
# {"title": "The Hobbit (Middle-Earth Universe)", "price": "17.80", "stock": 6}
#
# {"title": "The Makings of a Fatherless Child", "price": "31.58", "stock": 6}
#
# {"title": "The Perks of Being a Wallflower", "price": "55.02", "stock": 6}
#
# {"title": "The Sound Of Love", "price": "57.84", "stock": 6}
#
# {"title": "Miracles from Heaven: A Little Girl, Her Journey to Heaven, and Her Amazing Story of Healing", "price": "57.83", "stock": 3}
#
# {"title": "Myriad (Prentor #1)", "price": "58.75", "stock": 1}
#
# {"title": "Shadow Rites (Jane Yellowrock #10)", "price": "21.72", "stock": 1}
#
# {"title": "The Mirror & the Maze (The Wrath and the Dawn #1.5)", "price": "29.38", "stock": 1}
#
# {"title": "Sister Sable (The Mad Queen #1)", "price": "13.33", "stock": 1}
#
# {"title": "Origins (Alphas 0.5)", "price": "28.99", "stock": 1}
#
# {"title": "One Second (Seven #7)", "price": "52.94", "stock": 1}
#
# {"title": "Rise of the Rocket Girls: The Women Who Propelled Us, from Missiles to the Moon to Mars", "price": "41.67", "stock": 3}
#
# {"title": "Spilled Milk: Based on a True Story", "price": "49.51", "stock": 3}
#
# {"title": "Notes from a Small Island (Notes From a Small Island #1)", "price": "40.17", "stock": 3}
#
# {"title": "Outliers: The Story of Success", "price": "14.16", "stock": 3}
#
# {"title": "Night (The Night Trilogy #1)", "price": "13.51", "stock": 3}
#
# {"title": "Musicophilia: Tales of Music and the Brain", "price": "46.58", "stock": 6}
#
# {"title": "Ship Leaves Harbor: Essays on Travel by a Recovering Journeyman", "price": "30.60", "stock": 6}
#
# {"title": "Stiff: The Curious Lives of Human Cadavers", "price": "36.74", "stock": 3}
#
# {"title": "The Silent Twin (Detective Jennifer Knight #3)", "price": "36.25", "stock": 1}
#
# {"title": "Cosmos", "price": "36.17", "stock": 3}
#
# {"title": "#GIRLBOSS", "price": "50.96", "stock": 3}
#
# {"title": "Vampire Girl (Vampire Girl #1)", "price": "53.82", "stock": 1}
#
# {"title": "Manuscript Found in Accra", "price": "34.98", "stock": 3}
#
# {"title": "Fire Bound (Sea Haven/Sisters of the Heart #5)", "price": "21.28", "stock": 3}
#
# {"title": "The Iliad", "price": "16.16", "stock": 1}
#
# {"title": "The Communist Manifesto", "price": "14.76", "stock": 1}
#
# {"title": "Lord of the Flies", "price": "24.89", "stock": 1}
#
# {"title": "Trespassing Across America: One Man's Epic, Never-Done-Before (and Sort of Illegal) Hike Across the Heartland", "price": "53.51", "stock": 3}
#
# {"title": "The Name of God is Mercy", "price": "37.25", "stock": 3}
#
# {"title": "The Fault in Our Stars", "price": "47.22", "stock": 5}
#
# {"title": "What If?: Serious Scientific Answers to Absurd Hypothetical Questions", "price": "53.68", "stock": 5}
#
# {"title": "The Light of the Fireflies", "price": "54.43", "stock": 1}
#
# {"title": "The Blind Side: Evolution of a Game", "price": "53.71", "stock": 3}
#
# {"title": "Seven Days in the Art World", "price": "52.33", "stock": 3}
#
# {"title": "Sarah's Key", "price": "46.29", "stock": 3}
#
# {"title": "Rogue Lawyer (Rogue Lawyer #1)", "price": "50.11", "stock": 3}
#
# {"title": "The Case for Christ (Cases for Christianity)", "price": "47.84", "stock": 3}
#
# {"title": "The Catcher in the Rye", "price": "24.55", "stock": 3}
#
# {"title": "The Sense of an Ending", "price": "31.38", "stock": 2}
#
# {"title": "The Republic", "price": "33.78", "stock": 1}
#
# {"title": "The Odyssey", "price": "29.64", "stock": 1}
#
# {"title": "The Dream Thieves (The Raven Cycle #2)", "price": "34.50", "stock": 5}
#
# {"title": "Remember Me?", "price": "11.48", "stock": 5}
#
# {"title": "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy #1)", "price": "47.80", "stock": 3}
#
# {"title": "The Girl Who Kicked the Hornet's Nest (Millennium Trilogy #3)", "price": "57.48", "stock": 3}
#
# {"title": "The End of Faith: Religion, Terror, and the Future of Reason", "price": "22.13", "stock": 3}
#
# {"title": "Shiver (The Wolves of Mercy Falls #1)", "price": "16.23", "stock": 5}
#
# {"title": "The 5th Wave (The 5th Wave #1)", "price": "11.83", "stock": 5}
#
# {"title": "The Purpose Driven Life: What on Earth Am I Here for?", "price": "37.19", "stock": 3}
#
# {"title": "The Complete Poems", "price": "41.32", "stock": 3}
#
# {"title": "The Rest Is Noise: Listening to the Twentieth Century", "price": "34.77", "stock": 3}
#
# {"title": "Blue Lily, Lily Blue (The Raven Cycle #3)", "price": "34.13", "stock": 5}
#
# {"title": "Drama", "price": "38.70", "stock": 5}
#
# {"title": "Evicted: Poverty and Profit in the American City", "price": "42.27", "stock": 5}
#
# {"title": "Fool Me Once", "price": "16.96", "stock": 5}
#
# {"title": "Harry Potter and the Deathly Hallows (Harry Potter #7)", "price": "23.32", "stock": 5}
#
# {"title": "I Know Why the Caged Bird Sings (Maya Angelou's Autobiography #1)", "price": "36.55", "stock": 5}
#
# {"title": "If I Stay (If I Stay #1)", "price": "38.13", "stock": 5}
#
# {"title": "A Game of Thrones (A Song of Ice and Fire #1)", "price": "46.42", "stock": 5}
#
# {"title": "The Tipping Point: How Little Things Can Make a Big Difference", "price": "10.02", "stock": 3}
#
# {"title": "A Clash of Kings (A Song of Ice and Fire #2)", "price": "10.79", "stock": 5}
#
# {"title": "Eat, Pray, Love", "price": "51.32", "stock": 1}
#
# {"title": "The End of the Jesus Era (An Investigation #1)", "price": "14.40", "stock": 1}
#
# {"title": "Travels with Charley: In Search of America", "price": "57.82", "stock": 1}
#
# {"title": "The Tumor", "price": "41.56", "stock": 1}
#
# {"title": "H is for Hawk", "price": "57.42", "stock": 2}
#
# {"title": "Kindle Paperwhite User's Guide", "price": "34.00", "stock": 2}
#
# {"title": "Alight (The Generations Trilogy #2)", "price": "58.59", "stock": 5}
#
# {"title": "The Shining (The Shining #1)", "price": "27.88", "stock": 4}
#
# {"title": "The Hunger Games (The Hunger Games #1)", "price": "29.85", "stock": 4}
#
# {"title": "Vogue Colors A to Z: A Fashion Coloring Book", "price": "52.35", "stock": 4}
#
# {"title": "The Suffragettes (Little Black Classics, #96)", "price": "11.89", "stock": 2}
#
# {"title": "Are We Smart Enough to Know How Smart Animals Are?", "price": "56.58", "stock": 3}
#
# {"title": "A Walk in the Woods: Rediscovering America on the Appalachian Trail", "price": "30.48", "stock": 3}
#
# {"title": "Black Flags: The Rise of ISIS", "price": "40.87", "stock": 3}
#
# {"title": "Harry Potter and the Sorcerer's Stone (Harry Potter #1)", "price": "13.90", "stock": 4}
#
# {"title": "Mockingjay (The Hunger Games #3)", "price": "20.44", "stock": 4}
#
# {"title": "Outlander (Outlander #1)", "price": "19.67", "stock": 4}
#
# {"title": "Wild: From Lost to Found on the Pacific Crest Trail", "price": "46.02", "stock": 3}
#
# {"title": "World War Z: An Oral History of the Zombie War", "price": "21.80", "stock": 3}
#
# {"title": "Where'd You Go, Bernadette", "price": "18.13", "stock": 3}
#
# {"title": "Confessions of a Shopaholic (Shopaholic #1)", "price": "48.94", "stock": 4}
#
# {"title": "Zero History (Blue Ant #3)", "price": "34.77", "stock": 3}
#
# {"title": "Twilight (Twilight #1)", "price": "41.93", "stock": 3}
#
# {"title": "The Maze Runner (The Maze Runner #1)", "price": "20.93", "stock": 3}
#
# {"title": "The Paris Wife", "price": "36.80", "stock": 3}
#
# {"title": "The Lover's Dictionary", "price": "58.09", "stock": 3}
#
# {"title": "The Goldfinch", "price": "43.58", "stock": 3}
#
# {"title": "The Girl Who Played with Fire (Millennium Trilogy #2)", "price": "22.14", "stock": 3}
#
# {"title": "The Demon-Haunted World: Science as a Candle in the Dark", "price": "52.25", "stock": 3}
#
# {"title": "The Giver (The Giver Quartet #1)", "price": "12.30", "stock": 3}
#
# {"title": "Shopaholic & Baby (Shopaholic #5)", "price": "46.45", "stock": 3}
#
# {"title": "The Book Thief", "price": "53.49", "stock": 3}
#
# {"title": "The Autobiography of Malcolm X", "price": "23.43", "stock": 3}
#
# {"title": "Quiet: The Power of Introverts in a World That Can't Stop Talking", "price": "43.55", "stock": 3}
#
# {"title": "One for the Money (Stephanie Plum #1)", "price": "32.87", "stock": 3}
#
# {"title": "Orange Is the New Black", "price": "24.61", "stock": 3}
#
# {"title": "Packing for Mars: The Curious Science of Life in the Void", "price": "56.68", "stock": 3}
#
# {"title": "Life After Life", "price": "26.13", "stock": 3}
#
# {"title": "Morning Star (Red Rising #3)", "price": "29.40", "stock": 3}
#
# {"title": "Lean In: Women, Work, and the Will to Lead", "price": "25.02", "stock": 3}
#
# {"title": "Is Everyone Hanging Out Without Me? (And Other Concerns)", "price": "20.11", "stock": 3}
#
# {"title": "Gone Girl", "price": "37.60", "stock": 3}
#
# {"title": "Dark Places", "price": "23.90", "stock": 3}
#
# {"title": "Dead Wake: The Last Crossing of the Lusitania", "price": "39.24", "stock": 3}
#
# {"title": "David and Goliath: Underdogs, Misfits, and the Art of Battling Giants", "price": "17.81", "stock": 3}
#
# {"title": "Dracula", "price": "52.62", "stock": 3}
#
# {"title": "Fellside", "price": "38.62", "stock": 3}
#
# {"title": "Eclipse (Twilight #3)", "price": "18.74", "stock": 3}
#
# {"title": "Beautiful Creatures (Caster Chronicles #1)", "price": "21.55", "stock": 3}
#
# {"title": "Breaking Dawn (Twilight #4)", "price": "35.28", "stock": 3}
#
# {"title": "A Visit from the Goon Squad", "price": "14.08", "stock": 3}
#
# {"title": "The Zombie Room", "price": "19.69", "stock": 1}
#
# {"title": "The Name of the Wind (The Kingkiller Chronicle #1)", "price": "50.59", "stock": 1}
#
# {"title": "Taking Shots (Assassins #1)", "price": "18.88", "stock": 1}
#
# {"title": "Shatter Me (Shatter Me #1)", "price": "42.40", "stock": 1}
#
# {"title": "Paradise Lost (Paradise #1)", "price": "24.96", "stock": 1}
#
# {"title": "Jane Eyre", "price": "38.43", "stock": 1}
#
# {"title": "On the Road (Duluoz Legend)", "price": "32.36", "stock": 1}
#
# {"title": "Frankenstein", "price": "38.00", "stock": 1}

# %% [markdown]
# # RestFul API

# %% [markdown]
# Let's use API from data.gov.sg to check the PSI readings.
#
# https://api.data.gov.sg/v1/environment/psi
#
# When you click on the above link, you see that the data return is in json format.
#
# With reference to lecture slide 34 and 35, let's extract the PSI 24-hourly reading.

# %%
# importing the requests library
import requests 
# api-endpoint
URL = "https://api.data.gov.sg/v1/environment/psi"

# sending get request and saving the response as response object
r = requests.get(url = URL)

# %%
# extracting data in json format
data = r.json()
print(data)
# Out:
# {'region_metadata': [{'name': 'west', 'label_location': {'latitude': 1.35735, 'longitude': 103.7}}, {'name': 'national', 'label_location': {'latitude': 0, 'longitude': 0}}, {'name': 'east', 'label_location': {'latitude': 1.35735, 'longitude': 103.94}}, {'name': 'central', 'label_location': {'latitude': 1.35735, 'longitude': 103.82}}, {'name': 'south', 'label_location': {'latitude': 1.29587, 'longitude': 103.82}}, {'name': 'north', 'label_location': {'latitude': 1.41803, 'longitude': 103.82}}], 'items': [{'timestamp': '2021-05-20T18:00:00+08:00', 'update_timestamp': '2021-05-20T18:08:52+08:00', 'readings': {'o3_sub_index': {'west': 18, 'national': 33, 'east': 24, 'central': 23, 'south': 17, 'north': 33}, 'pm10_twenty_four_hourly': {'west': 38, 'national': 38, 'east': 30, 'central': 35, 'south': 35, 'north': 35}, 'pm10_sub_index': {'west': 38, 'national': 38, 'east': 30, 'central': 35, 'south': 35, 'north': 35}, 'co_sub_index': {'west': 3, 'national': 5, 'east': 5, 'central': 3, 'south': 5, 'north': 5}, 'pm25_twenty_four_hourly': {'west': 19, 'national': 21, 'east': 16, 'central': 20, 'south': 13, 'north': 21}, 'so2_sub_index': {'west': 8, 'national': 8, 'east': 3, 'central': 2, 'south': 3, 'north': 3}, 'co_eight_hour_max': {'west': 0.3, 'national': 0.55, 'east': 0.45, 'central': 0.32, 'south': 0.55, 'north': 0.51}, 'no2_one_hour_max': {'west': 43, 'national': 49, 'east': 42, 'central': 49, 'south': 39, 'north': 49}, 'so2_twenty_four_hourly': {'west': 13, 'national': 13, 'east': 6, 'central': 3, 'south': 5, 'north': 5}, 'pm25_sub_index': {'west': 58, 'national': 61, 'east': 55, 'central': 60, 'south': 52, 'north': 61}, 'psi_twenty_four_hourly': {'west': 58, 'national': 61, 'east': 55, 'central': 60, 'south': 52, 'north': 61}, 'o3_eight_hour_max': {'west': 42, 'national': 77, 'east': 57, 'central': 53, 'south': 41, 'north': 77}}}], 'api_info': {'status': 'healthy'}}

# %% [markdown]
# It is quite difficult to view the json data from the notebook. We can make use of online JSON Viewer such as http://jsonviewer.stack.hu/ to help us.
#
# From the json viewer, look for psi_twenty_four_hourly which is the data that we want to display.
#
# Note that the sample in lecture is reading pm25 one hourly reading, but now we want PSI 24-hourly reading.

# %%
# extracting PSI24 readings
readings = data['items'][0]['readings']['psi_twenty_four_hourly']
print("The PSI 24hourly readings are")
for r in readings:
  print("%s : %s"%(r, readings[r]))
# Out:
# The PSI 24hourly readings are
# west : 58
# national : 61
# east : 55
# central : 60
# south : 52
# north : 61
